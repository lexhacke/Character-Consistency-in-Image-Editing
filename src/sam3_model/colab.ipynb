# %%
# %cd /content
# !git clone https://github.com/lexhacke/Character-Consistency-in-Image-Editing
# %cd Character-Consistency-in-Image-Editing
# !git pull
# !pip install -r src/sam3_model/requirements.txt
# !pip install git+https://github.com/facebookresearch/sam3.git
# Out:
# /content
# fatal: destination path 'Character-Consistency-in-Image-Editing' already exists and is not an empty directory.
# /content/Character-Consistency-in-Image-Editing
# Already up to date.
# ...
#   Cloning https://github.com/facebookresearch/sam3.git to /tmp/pip-req-build-ldlzyb3a
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/sam3.git /tmp/pip-req-build-ldlzyb3a
#   Resolved https://github.com/facebookresearch/sam3.git to commit bfbed072a07a6a52c8d5fdc75a7a186251a835b1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.4
#     Uninstalling numpy-2.4.4:
# ...

# %%
from src.sam3_model.sam3_builder import sam3_builder

sam3_builder()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_28528/400442742.py in <cell line: 0>()
# ----> 1 from src.sam3_model.sam3_builder import sam3_builder
#       2
#       3 sam3_builder()
#
# /content/Character-Consistency-in-Image-Editing/src/sam3_model/sam3_builder.py in <module>
#       1 import requests
#       2 import pathlib
# ----> 3 import sam3
#       4 from sam3 import build_sam3_image_model
#       5
#
# /usr/local/lib/python3.12/dist-packages/sam3/__init__.py in <module>
#       3 # pyre-unsafe
#       4
# ----> 5 from .model_builder import build_sam3_image_model, build_sam3_predictor
#       6
#       7 __version__ = "0.1.0"
#
# /usr/local/lib/python3.12/dist-packages/sam3/model_builder.py in <module>
#      11 from huggingface_hub import hf_hub_download
#      12 from iopath.common.file_io import g_pathmgr
# ---> 13 from sam3.model.decoder import (
# ...
