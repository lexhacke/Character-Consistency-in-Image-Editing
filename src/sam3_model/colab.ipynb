# %%
# %cd /content
# !git clone https://github.com/lexhacke/Character-Consistency-in-Image-Editing
# !git pull origin main
# %cd Character-Consistency-in-Image-Editing
# !pip install -r requirements.txt
# Out:
# Cloning into 'Character-Consistency-in-Image-Editing'...
# remote: Enumerating objects: 306, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 306 (delta 25), reused 49 (delta 15), pack-reused 239 (from 1)
# Receiving objects: 100% (306/306), 320.24 MiB | 62.22 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# Updating files: 100% (116/116), done.
# /content/Character-Consistency-in-Image-Editing
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
