# %%
# %cd /content
# !git clone https://github.com/lexhacke/Character-Consistency-in-Image-Editing
# %cd Character-Consistency-in-Image-Editing
# !git pull
# !pip install -r src/sam3_model/requirements.txt
# Out:
# /content
# fatal: destination path 'Character-Consistency-in-Image-Editing' already exists and is not an empty directory.
# /content/Character-Consistency-in-Image-Editing
# Already up to date.
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 4)) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 5)) (0.25.0+cu128)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 8)) (1.0.26)
# Requirement already satisfied: numpy<2,>=1.26 in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 9)) (1.26.4)
# Requirement already satisfied: ftfy==6.1.1 in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 10)) (6.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 11)) (2025.11.3)
# Requirement already satisfied: iopath>=0.1.10 in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 12)) (0.1.10)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 13)) (4.15.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 20)) (4.67.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from -r src/sam3_model/requirements.txt (line 21)) (11.3.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.12/dist-packages (from ftfy==6.1.1->-r src/sam3_model/requirements.txt (line 10)) (0.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (3.25.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r src/sam3_model/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r src/sam3_model/requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm>=1.0.17->-r src/sam3_model/requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm>=1.0.17->-r src/sam3_model/requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from iopath>=0.1.10->-r src/sam3_model/requirements.txt (line 12)) (3.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (26.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (0.24.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r src/sam3_model/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r src/sam3_model/requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->-r src/sam3_model/requirements.txt (line 14)) (0.1.2)
# ERROR: sam3/ is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).

# %%
# !python src/sam3_model/tester.py
# Out:
# Using device: cuda
#
# [1] Building model...
# Traceback (most recent call last):
#   File "/content/Character-Consistency-in-Image-Editing/src/sam3_model/tester.py", line 19, in <module>
#     model = build_sam3_image_model(
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sam3/model_builder.py", line 593, in build_sam3_image_model
#     text_encoder = _create_text_encoder(bpe_path)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sam3/model_builder.py", line 488, in _create_text_encoder
#     tokenizer = SimpleTokenizer(bpe_path=bpe_path)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sam3/model/tokenizer_ve.py", line 138, in __init__
#     with g_pathmgr.open(bpe_path, "rb") as fh:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/iopath/common/file_io.py", line 1062, in open
#     bret = handler._open(path, mode, buffering=buffering, **kwargs)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/iopath/common/file_io.py", line 645, in _open
#     return open(  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/lib/python3.12/dist-packages/assets/bpe_simple_vocab_16e6.txt.gz'
