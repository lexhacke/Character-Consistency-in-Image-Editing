# %%
# %cd /content
# !git clone https://github.com/lexhacke/Character-Consistency-in-Image-Editing
# %cd Character-Consistency-in-Image-Editing
# !git pull
# !pip install -r src/requirements.txt
# Out:
# /content
# fatal: destination path 'Character-Consistency-in-Image-Editing' already exists and is not an empty directory.
# /content/Character-Consistency-in-Image-Editing
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 2), reused 6 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 2.30 KiB | 2.30 MiB/s, done.
# From https://github.com/lexhacke/Character-Consistency-in-Image-Editing
#    2a4ed85..a75b08a  main       -> origin/main
# Updating 2a4ed85..a75b08a
# Fast-forward
#  src/sam3_model/colab.ipynb | 57 ++++++++++++++++++++++++++++++
#  src/sam3_model/tester.py   | 88 ++++++++++++++++++++++++++++++++++++++++++++++
#  2 files changed, 145 insertions(+)
#  create mode 100644 src/sam3_model/tester.py
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !python src/sam3_model/tester.py
# Out:
# Traceback (most recent call last):
#   File "/content/Character-Consistency-in-Image-Editing/src/sam3_model/tester.py", line 11, in <module>
#     from sam3.model_builder import build_sam3_image_model
# ModuleNotFoundError: No module named 'sam3'
